# %%
from IPython.display import display, Image, clear_output, HTML
import time
import random
import requests
from bs4 import BeautifulSoup
import json
import time
import random

def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'

    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok

# %%
p1 = Image('Picture1.png', width = 300)
p2 = Image('Picture2.png', width = 300)
p3 = Image('Picture3.png', width = 300)

pq2 = Image('q2.png', width = 300)
pq3 = Image('q3.png', width = 300)

q1 = ["What is the color of the circle?", "What is the color of the star?", "Which shape was red?", "How many pentagons are in this grid? (give number)", "What was the first shape from the bottom row?"]
a1 = ["green", "yellow", "triangle", "0", "square"]
q2 = ["What colour was the star?", "What shape was above the square?", "Which shape was pink?", "What shape was between the diamond and triangle?", "What shape was in the indicated position?"]
a2 = ["red",  "circle", "cross", "circle", "rectangle"]
q3 = ["What is the color of the triangle?", "What is the color of the star?", "Which shape was in the middle?", "How many pentagons are in this grid? (give number)", "What was the first shape from the middle row?", "What shape was in the indicated position?"]
a3 = ["yellow", "yellow", "rectangle", "2", "pentagon", "square"]

complex1 = list(zip(q1, a1))
complex2 = list(zip(q2, a2))
complex3 = list(zip(q3, a3))
random.shuffle(complex1)
random.shuffle(complex2)
random.shuffle(complex3)
sq1, sa1 = zip(*complex1)
sq2, sa2 = zip(*complex2)
sq3, sa3 = zip(*complex3)

p6 = [p1, p2, p3]
pq6 = [0, pq2, pq3]
sq6 = [sq1, sq2, sq3]
sa6 = [sa1, sa2, sa3]



def test(p, pq, q, a):

    
    print("We are going to test your Memory!")

    print("Please enter your name:")
    name = input("> ")

    print("Please enter your age:")
    age = input("> ")
    clear_output()
    
    print("You will have to answer 9 quenstions, each worth one point")
    time.sleep(1)

    print("The time taken is also measured, and compared with others")
    time.sleep(1)

    print("You will have 5 seconds to see the grid:")
    time.sleep(1)


    print('Here comes the questions:')
    time.sleep(2)

    
    clear_output()

    global score
    score = 0
     
    time.sleep(2)
    for j in range (3):
        
        time.sleep(1)
        clear_output()
        
        print('Here is the graph', j+1)
        display(p[j])
        time.sleep(10)
        for i in range(3):
            time.sleep(1)
            clear_output()
            ans = ""
            que = f"{q[j][i]}"
            if que == "What shape was in the indicated position?":
                print(que)
                display(pq[j])
                ans = str(input(""))
                if ans == a[j][i]:
                    score += 1
                    print("correct")
                else:
                    print("incorrect")
            else:
                print(que)
                ans = str(input(""))
                if ans == a[j][i]:
                    score += 1
                    print("correct")
                else:
                    print("incorrect")


    print("Well done!")
    time.sleep(1)
    clear_output()
    print(f"You have answered {score} questions correctly")
    print('Thank you for taking the test!')
    
    data_dict = {

    'name': name,

    'age': age,

    'score': score

    }

    form_url = "https://docs.google.com/forms/d/e/1FAIpQLSdmkg_7aqPT3RXZ_UxSJ_oRh-oMUF1W7JjWZztBaWxs9tPjUQ/viewform?usp=sf_link" # paste your form URL as a string here

    print("Please read:")

    print("")

    print("we wish to record your response data")

    print("to an anonymised public data repository. ")

    print("Your data will be used for educational teaching purposes")

    print("practising data analysis and visualisation.")

    print("")

    print("Please type yes in the box below if you consent to the upload.")

    result = input("> ")

    if result == "yes":

        print("Thanks - your data will be uploaded.")

        send_to_google_form(data_dict, form_url)

    else:

        print("No problem we hope you enjoyed the test.")
    
    return

test(p6, pq6, sq6, sa6)
# Out:
# You have answered 3 questions correctly
# Thank you for taking the test!
# Please read:
#
# we wish to record your response data
# to an anonymised public data repository.
# Your data will be used for educational teaching purposes
# practising data analysis and visualisation.
#
# Please type yes in the box below if you consent to the upload.
# >  yes
# Thanks - your data will be uploaded.
